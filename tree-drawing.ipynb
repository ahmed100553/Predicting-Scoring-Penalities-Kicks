# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import datasets
from IPython.display import Image  
from sklearn import tree
import pydotplus
import pandas as pd
import numpy as np

# %%
scoring = pd.read_csv("Scoring.csv")

# %%
X = scoring.drop(['Target'],axis=1)
X
# Out:
#     Acceleration  Speed(m/s)  Angle
# 0          201.0       22.00   39.3
# 1          156.0       34.00   42.0
# 2          195.0       33.00   62.0
# 3          186.0       28.00   32.0
# 4           73.0       24.00   10.5
# 5          160.0       41.00   49.0
# 6           83.5       36.00   11.8
# 7          121.0       21.00   45.0
# 8          118.0       17.60   41.8
# 9          292.0       17.35   56.0
# 10         305.0       19.82   58.0
# 11         210.0       18.26   59.0
# 12         132.0       29.00   65.0
# 13         114.0       20.00   22.0
# 14         250.0       22.00   11.6
# 15         196.0       19.00   18.0
# 16         407.0       31.00    9.0
# 17         179.0       48.60    9.8
# 18          87.0       16.00   17.0
# 19         156.0       23.00   12.0
# 20          61.0       15.00    9.0
# 21          18.0        6.52   11.3
# 22         116.0       27.60   13.2
# 23          38.1       21.50    9.6

# %%
y=scoring['Target']
y
# Out:
# 0         Scored
# 1         Scored
# 2         Scored
# 3         Scored
# 4     Not-scored
# 5         Scored
# 6     Not-scored
# 7         Scored
# 8         Scored
# 9         Scored
# 10        Scored
# 11        Scored
# 12        Scored
# 13        Scored
# 14        Scored
# 15        Scored
# 16    Not-scored
# 17    Not-scored
# 18    Not-scored
# 19    Not-scored
# 20    Not-scored
# 21    Not-scored
# 22    Not-scored
# 23    Not-scored
# Name: Target, dtype: object

# %%
clf = DecisionTreeClassifier(random_state=0)
# Train model
model = clf.fit(X, y)

# %%
dot_data = tree.export_graphviz(clf, out_file=None, 
                                feature_names=['Acceleration','Speed(m/s)','Angle'],  
                                class_names=['scored', 'Not-scored'])

# Draw graph
graph = pydotplus.graph_from_dot_data(dot_data)  

# Show graph
Image(graph.create_png())
